# %%
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Chargement les donnees dans une df & affichage les 5 premiers lignes

# %%
df=pd.read_csv(r"C:\Users\PRO\Desktop\Morocco Education Data Intelligence Platform\data\bronze\ds1_eleves.csv")
df.head()
# Out:
#    id_eleve annee_scolaire                     region code_region  \
# 0  EL100000      2015-2016  Tanger-Tétouan-Al Hoceïma         TAN
# 1  EL100001      2018-2019             Marrakech-Safi         MAR
# 2  EL100002      2021-2022       Béni Mellal-Khénifra         BMK
# 3  EL100003      2018-2019  Tanger-Tétouan-Al Hoceïma         TAN
# 4  EL100004      2016-2017          Casablanca-Settat         CAS
#
#           province  milieu secteur       cycle     genre  age  redoublant  \
# 0          Tétouan  Urbain  Public    Primaire  Masculin   11           0
# 1        Marrakech   Rural  Public    Primaire   Féminin   10           0
# 2  Fquih Ben Salah   Rural   Privé    Primaire  Masculin    8           0
# 3       Fahs-Anjra  Urbain  Public  Qualifiant   Féminin   17           0
# 4           Settat   Rural  Public   Collégial   Féminin   14           0
#
#    score_moyen  a_abandonne          motif_abandon  beneficiaire_bourse  \
# ...

# %% [markdown]
# # Les informations du dataframe

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_eleve             15000 non-null  str
#  1   annee_scolaire       15000 non-null  str
#  2   region               15000 non-null  str
#  3   code_region          15000 non-null  str
#  4   province             15000 non-null  str
#  5   milieu               15000 non-null  str
#  6   secteur              15000 non-null  str
#  7   cycle                15000 non-null  str
#  8   genre                15000 non-null  str
#  9   age                  15000 non-null  int64
#  10  redoublant           15000 non-null  int64
#  11  score_moyen          15000 non-null  float64
#  12  a_abandonne          15000 non-null  int64
#  13  motif_abandon        1400 non-null   str
#  14  beneficiaire_bourse  15000 non-null  int64
#  15  acces_cantine        15000 non-null  int64
# ...

# %% [markdown]
# # les noms du colonnes

# %%
df.columns
# Out:
# Index(['id_eleve', 'annee_scolaire', 'region', 'code_region', 'province',
#        'milieu', 'secteur', 'cycle', 'genre', 'age', 'redoublant',
#        'score_moyen', 'a_abandonne', 'motif_abandon', 'beneficiaire_bourse',
#        'acces_cantine', 'acces_internat'],
#       dtype='str')

# %% [markdown]
# # Type de chaque colonne

# %%
df.dtypes
# Out:
# id_eleve                   str
# annee_scolaire             str
# region                     str
# code_region                str
# province                   str
# milieu                     str
# secteur                    str
# cycle                      str
# genre                      str
# age                      int64
# redoublant               int64
# score_moyen            float64
# a_abandonne              int64
# motif_abandon              str
# beneficiaire_bourse      int64
# acces_cantine            int64
# acces_internat           int64
# dtype: object

# %% [markdown]
# # Afficher les statistiques du dataframe

# %%
df.describe()
# Out:
#                 age    redoublant   score_moyen   a_abandonne  \
# count  15000.000000  15000.000000  15000.000000  15000.000000
# mean      12.637933      0.167333     11.276321      0.093333
# std        5.334811      0.373286      2.862543      0.290909
# min        4.000000      0.000000      0.380000      0.000000
# 25%        8.000000      0.000000      9.360000      0.000000
# 50%       12.000000      0.000000     11.260000      0.000000
# 75%       16.000000      0.000000     13.200000      0.000000
# max       27.000000      1.000000     20.000000      1.000000
#
#        beneficiaire_bourse  acces_cantine  acces_internat
# count         15000.000000   15000.000000    15000.000000
# mean              0.282600       0.347133        0.120067
# std               0.450279       0.476074        0.325050
# min               0.000000       0.000000        0.000000
# 25%               0.000000       0.000000        0.000000
# ...

# %%
df.value_counts()
# Out:
# id_eleve  annee_scolaire  region                     code_region  province         milieu  secteur  cycle        genre     age  redoublant  score_moyen  a_abandonne  motif_abandon             beneficiaire_bourse  acces_cantine  acces_internat
# EL100002  2021-2022       Béni Mellal-Khénifra       BMK          Fquih Ben Salah  Rural   Privé    Primaire     Masculin  8    0           12.69        1            Difficultés scolaires     1                    0              0                 1
# EL100016  2021-2022       Fès-Meknès                 FES          Fès              Rural   Public   Primaire     Féminin   10   0           13.94        1            Travail enfant            0                    0              1                 1
# EL100028  2019-2020       Casablanca-Settat          CAS          El Jadida        Urbain  Public   Collégial    Féminin   13   0           6.90         1            Difficultés scolaires     0                    1              0                 1
# ...

# %%
df.nunique()
# Out:
# id_eleve               15000
# annee_scolaire             9
# region                    12
# code_region               12
# province                  71
# milieu                     2
# secteur                    2
# cycle                      6
# genre                      2
# age                       24
# redoublant                 2
# score_moyen             1500
# a_abandonne                2
# motif_abandon              9
# beneficiaire_bourse        2
# acces_cantine              2
# acces_internat             2
# dtype: int64

# %% [markdown]
# # Calculer le taux des valeurs manquantes

# %%
is_null=df.isnull().mean()*100
is_null
# Out:
# id_eleve                0.000000
# annee_scolaire          0.000000
# region                  0.000000
# code_region             0.000000
# province                0.000000
# milieu                  0.000000
# secteur                 0.000000
# cycle                   0.000000
# genre                   0.000000
# age                     0.000000
# redoublant              0.000000
# score_moyen             0.000000
# a_abandonne             0.000000
# motif_abandon          90.666667
# beneficiaire_bourse     0.000000
# acces_cantine           0.000000
# acces_internat          0.000000
# dtype: float64

# %% [markdown]
# # Visualiser les valeurs manquantes par colonne

# %%
is_null.plot(kind='bar')
plt.title("Valeurs manquantes par colonne")
plt.show()

# %%
double=df.duplicated().sum()
double
# Out:
# np.int64(0)

# %% [markdown]
# # Connaitre les Outliers

# %%
# Sélection des colonnes numériques
numeric_df = df.select_dtypes(include="number")

# Calcul du skewness
skewness = numeric_df.skew()

print(skewness)
# Out:
# age                    0.362492
# redoublant             1.782608
# score_moyen           -0.011036
# a_abandonne            2.796210
# beneficiaire_bourse    0.965753
# acces_cantine          0.642282
# acces_internat         2.338001
# dtype: float64
