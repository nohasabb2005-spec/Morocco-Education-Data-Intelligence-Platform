# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\PRO\Desktop\Morocco Education Data Intelligence Platform\data\bronze\ds4_examens_nationaux.csv")
df.head()
# Out:
#   id_candidat  annee         type_examen         filiere              region  \
# 0  CAND300000   2018        Baccalauréat        Economie  Rabat-Salé-Kénitra
# 1  CAND300001   2019        Baccalauréat  Sciences maths          Fès-Meknès
# 2  CAND300002   2019        Baccalauréat         Lettres   Casablanca-Settat
# 3  CAND300003   2021  Brevet (Collégial)             NaN      Marrakech-Safi
# 4  CAND300004   2015  Brevet (Collégial)             NaN      Drâa-Tafilalet
#
#   code_region  milieu secteur     genre  note_arabe  note_mathematiques  \
# 0         RAB  Urbain  Public  Masculin       12.85                9.81
# 1         FES  Urbain  Public  Masculin        8.98               17.40
# 2         CAS   Rural  Public   Féminin        8.77               11.35
# 3         MAR  Urbain  Public   Féminin        9.86               11.47
# 4         DRA  Urbain   Privé  Masculin        7.80               11.60
#
#    note_francais  note_sciences  note_histoire_geo  note_education_islamique  \
# 0           5.31           9.51               6.43                      7.52
# 1          13.18          14.24              11.03                     11.75
# 2           8.91           6.87              13.07                     11.29
# 3          10.41           9.16               9.92                     12.37
# 4          11.32          16.24               6.86                     12.38
#
#    moyenne_generale  admis     mention
# 0              8.78      0     Ajourné
# 1             12.91      1  Assez Bien
# 2              9.41      0     Ajourné
# 3             10.53      1    Passable
# 4             12.07      1  Assez Bien

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_candidat               10000 non-null  str
#  1   annee                     10000 non-null  int64
#  2   type_examen               10000 non-null  str
#  3   filiere                   4471 non-null   str
#  4   region                    10000 non-null  str
#  5   code_region               10000 non-null  str
#  6   milieu                    10000 non-null  str
#  7   secteur                   10000 non-null  str
#  8   genre                     10000 non-null  str
#  9   note_arabe                10000 non-null  float64
#  10  note_mathematiques        10000 non-null  float64
#  11  note_francais             10000 non-null  float64
#  12  note_sciences             10000 non-null  float64
#  13  note_histoire_geo         10000 non-null  float64
#  14  note_education_islamique  10000 non-null  float64
#  15  moyenne_generale          10000 non-null  float64
#  16  admis                     10000 non-null  int64
#  17  mention                   10000 non-null  str
# dtypes: float64(7), int64(2), str(9)
# memory usage: 1.4 MB

# %%
df.columns
# Out:
# Index(['id_candidat', 'annee', 'type_examen', 'filiere', 'region',
#        'code_region', 'milieu', 'secteur', 'genre', 'note_arabe',
#        'note_mathematiques', 'note_francais', 'note_sciences',
#        'note_histoire_geo', 'note_education_islamique', 'moyenne_generale',
#        'admis', 'mention'],
#       dtype='str')

# %%
df.dtypes
# Out:
# id_candidat                     str
# annee                         int64
# type_examen                     str
# filiere                         str
# region                          str
# code_region                     str
# milieu                          str
# secteur                         str
# genre                           str
# note_arabe                  float64
# note_mathematiques          float64
# note_francais               float64
# note_sciences               float64
# note_histoire_geo           float64
# note_education_islamique    float64
# moyenne_generale            float64
# admis                         int64
# mention                         str
# dtype: object

# %%
null=df.isnull().mean()*100
null
# Out:
# id_candidat                  0.00
# annee                        0.00
# type_examen                  0.00
# filiere                     55.29
# region                       0.00
# code_region                  0.00
# milieu                       0.00
# secteur                      0.00
# genre                        0.00
# note_arabe                   0.00
# note_mathematiques           0.00
# note_francais                0.00
# note_sciences                0.00
# note_histoire_geo            0.00
# note_education_islamique     0.00
# moyenne_generale             0.00
# admis                        0.00
# mention                      0.00
# dtype: float64

# %%
null.plot(kind='bar')
plt.title("Valeurs manquantes par colonne")
plt.show()

# %%
df.value_counts()
# Out:
# id_candidat  annee  type_examen   filiere         region                code_region  milieu  secteur  genre     note_arabe  note_mathematiques  note_francais  note_sciences  note_histoire_geo  note_education_islamique  moyenne_generale  admis  mention
# CAND300000   2018   Baccalauréat  Economie        Rabat-Salé-Kénitra    RAB          Urbain  Public   Masculin  12.85       9.81                5.31           9.51           6.43               7.52                      8.78              0      Ajourné       1
# CAND300001   2019   Baccalauréat  Sciences maths  Fès-Meknès            FES          Urbain  Public   Masculin  8.98        17.40               13.18          14.24          11.03              11.75                     12.91             1      Assez Bien    1
# CAND300002   2019   Baccalauréat  Lettres         Casablanca-Settat     CAS          Rural   Public   Féminin   8.77        11.35               8.91           6.87           13.07              11.29                     9.41              0      Ajourné       1
# CAND300008   2023   Baccalauréat  Sciences maths  Rabat-Salé-Kénitra    RAB          Rural   Public   Féminin   10.36       13.48               11.86          7.86           14.18              13.96                     11.30             1      Passable      1
# CAND300012   2019   Baccalauréat  Sciences maths  Rabat-Salé-Kénitra    RAB          Urbain  Public   Masculin  10.62       7.97                6.01           17.32          10.37              13.31                     10.90             1      Passable      1
#                                                                                                                                                                                                                                                                  ..
# CAND309991   2016   Baccalauréat  Sciences maths  Souss-Massa           SOU          Urbain  Public   Masculin  14.29       7.77                14.06          9.52           6.22               10.39                     10.34             1      Passable      1
# CAND309994   2023   Baccalauréat  Arts            Rabat-Salé-Kénitra    RAB          Urbain  Public   Masculin  7.74        4.90                11.91          11.74          10.55              13.97                     9.83              0      Ajourné       1
# CAND309995   2019   Baccalauréat  Lettres         Béni Mellal-Khénifra  BMK          Urbain  Privé    Masculin  8.77        11.01               7.72           11.59          11.98              13.52                     11.73             1      Passable      1
# CAND309997   2015   Baccalauréat  Lettres         Drâa-Tafilalet        DRA          Rural   Public   Masculin  11.70       11.06               10.85          9.11           6.78               13.63                     9.95              0      Ajourné       1
# CAND309998   2018   Baccalauréat  Sciences maths  Fès-Meknès            FES          Rural   Public   Masculin  12.83       10.43               10.45          9.40           9.32               11.89                     10.14             1      Passable      1
# Name: count, Length: 4471, dtype: int64

# %%
double=df.duplicated().sum()
double
# Out:
# np.int64(0)

# %%
# Sélection des colonnes numériques
numeric_df = df.select_dtypes(include="number")

# Calcul du skewness
skewness = numeric_df.skew()

print(skewness)
# Out:
# annee                      -0.020739
# note_arabe                 -0.028664
# note_mathematiques          0.027673
# note_francais              -0.020021
# note_sciences              -0.020225
# note_histoire_geo          -0.008605
# note_education_islamique   -0.004145
# moyenne_generale            0.058383
# admis                      -0.638301
# dtype: float64
