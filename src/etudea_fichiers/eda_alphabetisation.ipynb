# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\PRO\Desktop\Morocco Education Data Intelligence Platform\data\bronze\ds8_alphabetisation_adultes.csv")
df.head()
# Out:
#   id_beneficiaire  annee                region code_region         province  \
# 0       ALP500000   2022              Oriental         ORI          Berkane
# 1       ALP500001   2021           Souss-Massa         SOU       Taroudannt
# 2       ALP500002   2015     Casablanca-Settat         CAS       Mohammadia
# 3       ALP500003   2019  Béni Mellal-Khénifra         BMK  Fquih Ben Salah
# 4       ALP500004   2021            Fès-Meknès         FES    Moulay Yacoub
#
#    milieu    genre  age tranche_age               operateur  \
# 0  Urbain  Féminin   62       50-64  Association partenaire
# 1   Rural  Féminin   60       50-64                   ANLCA
# 2  Urbain  Féminin   24       15-24                   ANLCA
# 3   Rural  Féminin   52       50-64                   ANLCA
# 4   Rural  Féminin   21       15-24                   ANLCA
#
#            niveau_formation  heures_formation  formation_completee  \
# 0  Niveau 2 (intermédiaire)               168                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_beneficiaire         4000 non-null   str
#  1   annee                   4000 non-null   int64
#  2   region                  4000 non-null   str
#  3   code_region             4000 non-null   str
#  4   province                4000 non-null   str
#  5   milieu                  4000 non-null   str
#  6   genre                   4000 non-null   str
#  7   age                     4000 non-null   int64
#  8   tranche_age             3934 non-null   str
#  9   operateur               4000 non-null   str
#  10  niveau_formation        4000 non-null   str
#  11  heures_formation        4000 non-null   int64
#  12  formation_completee     4000 non-null   int64
#  13  score_evaluation_final  4000 non-null   float64
# dtypes: float64(1), int64(4), str(9)
# memory usage: 437.6 KB

# %%
df.columns
# Out:
# Index(['id_beneficiaire', 'annee', 'region', 'code_region', 'province',
#        'milieu', 'genre', 'age', 'tranche_age', 'operateur',
#        'niveau_formation', 'heures_formation', 'formation_completee',
#        'score_evaluation_final'],
#       dtype='str')

# %%
df.dtypes
# Out:
# id_beneficiaire               str
# annee                       int64
# region                        str
# code_region                   str
# province                      str
# milieu                        str
# genre                         str
# age                         int64
# tranche_age                   str
# operateur                     str
# niveau_formation              str
# heures_formation            int64
# formation_completee         int64
# score_evaluation_final    float64
# dtype: object

# %%
val_null=df.isnull().mean()*100
val_null
# Out:
# id_beneficiaire           0.00
# annee                     0.00
# region                    0.00
# code_region               0.00
# province                  0.00
# milieu                    0.00
# genre                     0.00
# age                       0.00
# tranche_age               1.65
# operateur                 0.00
# niveau_formation          0.00
# heures_formation          0.00
# formation_completee       0.00
# score_evaluation_final    0.00
# dtype: float64

# %%
val_null.plot(kind='bar',color="red")
plt.title("valeurs manquantes pour chaque colonne")
plt.show()

# %%
double=df.duplicated().sum()
double
# Out:
# np.int64(0)

# %%
# Sélection des colonnes numériques
numeric_df = df.select_dtypes(include="number")

# Calcul du skewness
skewness = numeric_df.skew()

print(skewness)
# Out:
# annee                    -0.022960
# age                      -0.028277
# heures_formation         -0.031330
# formation_completee      -0.808088
# score_evaluation_final   -0.143514
# dtype: float64
