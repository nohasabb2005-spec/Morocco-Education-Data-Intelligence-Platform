# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\PRO\Desktop\Morocco Education Data Intelligence Platform\data\bronze\ds7_abandons_scolaires.csv")
df.head()
# Out:
#   id_abandon annee_scolaire                     region code_region  \
# 0   AB400000      2016-2017                Souss-Massa         SOU
# 1   AB400001      2023-2024                 Fès-Meknès         FES
# 2   AB400002      2018-2019  Tanger-Tétouan-Al Hoceïma         TAN
# 3   AB400003      2017-2018  Tanger-Tétouan-Al Hoceïma         TAN
# 4   AB400004      2020-2021  Tanger-Tétouan-Al Hoceïma         TAN
#
#                province  milieu      cycle niveau_classe     genre  \
# 0  Inezgane-Ait Melloul  Urbain   Primaire       Année 5   Féminin
# 1                   Fès   Rural   Primaire       Année 4  Masculin
# 2               Larache   Rural  Collégial       Année 3  Masculin
# 3           Chefchaouen   Rural   Primaire       Année 3  Masculin
# 4        Tanger-Assilah  Urbain  Collégial       Année 1  Masculin
#
#    age_abandon                 motif_principal distance_etablissement  \
# 0            7         Difficultés économiques                 1–5 km
# ...

# %%
df.shape
# Out:
# (5000, 16)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_abandon              5000 non-null   str
#  1   annee_scolaire          5000 non-null   str
#  2   region                  5000 non-null   str
#  3   code_region             5000 non-null   str
#  4   province                5000 non-null   str
#  5   milieu                  5000 non-null   str
#  6   cycle                   5000 non-null   str
#  7   niveau_classe           5000 non-null   str
#  8   genre                   5000 non-null   str
#  9   age_abandon             5000 non-null   int64
#  10  motif_principal         5000 non-null   str
#  11  distance_etablissement  5000 non-null   str
#  12  revenu_menage_mensuel   5000 non-null   str
#  13  nb_enfants_menage       5000 non-null   int64
#  14  parent_analphabete      5000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['id_abandon', 'annee_scolaire', 'region', 'code_region', 'province',
#        'milieu', 'cycle', 'niveau_classe', 'genre', 'age_abandon',
#        'motif_principal', 'distance_etablissement', 'revenu_menage_mensuel',
#        'nb_enfants_menage', 'parent_analphabete', 'retour_ecole'],
#       dtype='str')

# %%
df.dtypes
# Out:
# id_abandon                  str
# annee_scolaire              str
# region                      str
# code_region                 str
# province                    str
# milieu                      str
# cycle                       str
# niveau_classe               str
# genre                       str
# age_abandon               int64
# motif_principal             str
# distance_etablissement      str
# revenu_menage_mensuel       str
# nb_enfants_menage         int64
# parent_analphabete        int64
# retour_ecole              int64
# dtype: object

# %%
double=df.duplicated().sum()
double
# Out:
# np.int64(0)

# %%
df["distance_etablissement"].value_counts()
# Out:
# distance_etablissement
# 1–5 km     1764
# < 1 km     1498
# 5–15 km    1003
# > 15 km     735
# Name: count, dtype: int64

# %%
df["revenu_menage_mensuel"].value_counts()
# Out:
# revenu_menage_mensuel
# 2000-4000 MAD    1746
# < 2000 MAD       1441
# 4000-7000 MAD    1146
# > 7000 MAD        667
# Name: count, dtype: int64

# %%
df["distance_etablissement"].nunique()
# Out:
# 4

# %%
df['revenu_menage_mensuel'].nunique()
# Out:
# 4

# %%
# Sélection des colonnes numériques
numeric_df = df.select_dtypes(include="number")

# Calcul du skewness
skewness = numeric_df.skew()

print(skewness)
# Out:
# age_abandon          -0.499059
# nb_enfants_menage    -0.010423
# parent_analphabete   -0.201880
# retour_ecole          0.969237
# dtype: float64
